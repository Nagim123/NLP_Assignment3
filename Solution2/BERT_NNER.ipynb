# %% [markdown]
# # Data converting

# %% [markdown]
# ## Install tokenizer
# For Russian text we will use **razdel** tokenizer.

# %%
# !pip install razdel
# Out:
# Collecting razdel
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Installing collected packages: razdel
# Successfully installed razdel-0.5.0

# %%
from razdel import tokenize

tokens = list(tokenize('Проверка токенизатора на русском языке, да-да, Иван Иванович.'))
tokens
# Out:
# [Substring(0, 8, 'Проверка'),
#  Substring(9, 21, 'токенизатора'),
#  Substring(22, 24, 'на'),
#  Substring(25, 32, 'русском'),
#  Substring(33, 38, 'языке'),
#  Substring(38, 39, ','),
#  Substring(40, 45, 'да-да'),
#  Substring(45, 46, ','),
#  Substring(47, 51, 'Иван'),
#  Substring(52, 60, 'Иванович'),
#  Substring(60, 61, '.')]

# %% [markdown]
# ## Download dataset
# I uploaded the datasets to google disk, so we will use *gdown* to get them.

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1Fe7yaIFt59iCq0ILI88HU7Ej9XE6S3bu/view?usp=sharing
# !wget https://huggingface.co/datasets/iluvvatar/RuNNE/raw/main/data/test.jsonl
# !gdown --fuzzy https://drive.google.com/file/d/1kDWIe5KSZdB4ipiNNBRvT9t-FW2ZkkeW/view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Fe7yaIFt59iCq0ILI88HU7Ej9XE6S3bu
# To: /content/train.jsonl
# 100% 7.31M/7.31M [00:00<00:00, 265MB/s]
# --2024-04-18 10:54:36--  https://huggingface.co/datasets/iluvvatar/RuNNE/raw/main/data/test.jsonl
# Resolving huggingface.co (huggingface.co)... 18.172.134.24, 18.172.134.4, 18.172.134.124, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 403934 (394K) [text/plain]
# Saving to: ‘test.jsonl’
#
# test.jsonl          100%[===================>] 394.47K  --.-KB/s    in 0.04s
#
# 2024-04-18 10:54:36 (9.00 MB/s) - ‘test.jsonl’ saved [403934/403934]
#
# Downloading...
# From: https://drive.google.com/uc?id=1kDWIe5KSZdB4ipiNNBRvT9t-FW2ZkkeW
# To: /content/validation.jsonl
# 100% 1.77M/1.77M [00:00<00:00, 182MB/s]

# %%
from razdel import tokenize, sentenize
import json

def read_training_dataset(file_name: str) -> None:
    """
    Read dataset in .jsonl format and save it as .txt 'TOKEN TAG1, TAG2 \n'

    Parameters:
        file_name (str): Path to dataset file.
    """
    annotated_sentences = []


    with open(f"{file_name}.jsonl") as dataset_file:
        lines = dataset_file.readlines()

    # Go through each line
    for line in lines:
        # Load content
        content = json.loads(line)
        # Get token data
        text = content["text"]
        tokens = list(tokenize(text))
        sentences = list(sentenize(text))
        end_positions = [sentence.stop for sentence in sentences]

        # Get NERs data
        nested_ners = [[] for _ in tokens]
        content_entities = [entity.split(" ") for entity in content["entities"]]
        content_entities.sort(key=lambda x: (int(x[0]) - int(x[1])))

        # For each NER
        for entity in content_entities:
            start, end, entity_type = entity
            start, end = int(start), int(end)
            begin_placed = False
            # Find token it linked with
            for i in range(len(tokens)):
                if tokens[i].start >= start and tokens[i].stop <= end:
                    if begin_placed:
                        # If it is not the first token in a span mark it as continue (I)
                        nested_ners[i].append(f"I-{entity_type}")
                    else:
                        # If it the first token in a span mark it as begin (B)
                        begin_placed = True
                        nested_ners[i].append(f"B-{entity_type}")
        # Write the processed data to .txt file
        current_end = 0
        with open(f"{file_name}.txt", "a") as txt_file:
            for token, nner in zip(tokens, nested_ners):
                txt_file.write(f"{token.text} {'O' if len(nner) == 0 else ' '.join(nner)}\n")
                if token.stop >= end_positions[current_end]:
                    current_end += 1
                    txt_file.write("\n")

# %%
# Process each type of files
read_training_dataset("train")
read_training_dataset("test")
read_training_dataset("validation")

# %% [markdown]
# ## Prepare data for training
# Prepare data for ArabiNER model.

# %%
# !git clone https://github.com/SinaLab/ArabicNER
# Out:
# Cloning into 'ArabicNER'...
# remote: Enumerating objects: 595, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 595 (delta 15), reused 12 (delta 8), pack-reused 566
# Receiving objects: 100% (595/595), 284.95 KiB | 3.65 MiB/s, done.
# Resolving deltas: 100% (355/355), done.

# %%
# !mkdir ArabicNER/RuNNE
# !mkdir ArabicNER/output
# !cp train.txt ArabicNER/RuNNE
# !cp test.txt ArabicNER/RuNNE
# !cp validation.txt ArabicNER/RuNNE

# %%
! echo $PYTHONPATH

# Add ArabiNER to path so we can import it as module
import os
os.environ['PYTHONPATH'] += ":ArabicNER"

! echo $PYTHONPATH
# Out:
# /env/python
# /env/python:ArabicNER

# %%
# !pip install seqeval
# Out:
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 792.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.4.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=5689678e653f07ded4361ce70aeed35f4c15224b081699ffa0829beabc0deee1
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %% [markdown]
# # Train ArabiNER

# %%
# !python ArabicNER/arabiner/bin/train.py \
    --output_path ArabicNER/results \
    --train_path ArabicNER//RuNNE/train.txt \
    --val_path ArabicNER//RuNNE/validation.txt \
    --test_path ArabicNER//RuNNE/test.txt \
    --batch_size 16 \
    --data_config '{"fn":"arabiner.data.datasets.NestedTagsDataset","kwargs":{"max_seq_len":512}}' \
    --trainer_config '{"fn":"arabiner.trainers.BertNestedTrainer","kwargs":{"max_epochs":15}}' \
    --network_config '{"fn":"arabiner.nn.BertNestedTagger","kwargs":{"dropout":0.1,"bert_model":"DeepPavlov/rubert-base-cased"}}' \
    --optimizer '{"fn":"torch.optim.AdamW","kwargs":{"lr":0.0001}}'
# Out:
# 2024-04-14 20:54:33.220520: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-14 20:54:33.220573: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-14 20:54:33.221880: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-14 20:54:33.228786: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-14 20:54:34.289037: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Logging to ArabicNER/results/train.log
# INFO	__main__	Sun, 14 Apr 2024 20:54:45	Writing config to ArabicNER/results/args.json
# tokenizer_config.json: 100% 24.0/24.0 [00:00<00:00, 116kB/s]
# vocab.txt: 100% 1.65M/1.65M [00:00<00:00, 2.21MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 374kB/s]
# config.json: 100% 642/642 [00:00<00:00, 3.48MB/s]
# INFO	arabiner.utils.data	Sun, 14 Apr 2024 20:54:49	596 batches found
# INFO	arabiner.utils.data	Sun, 14 Apr 2024 20:54:49	146 batches found
# INFO	arabiner.utils.data	Sun, 14 Apr 2024 20:54:50	79 batches found
# pytorch_model.bin: 100% 714M/714M [00:06<00:00, 108MB/s]
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:05	Epoch 0 | Batch 10/596 | Timestep 10 | LR 0.0001000000 | Loss 9.462429
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:08	Epoch 0 | Batch 20/596 | Timestep 20 | LR 0.0001000000 | Loss 4.777143
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:10	Epoch 0 | Batch 30/596 | Timestep 30 | LR 0.0001000000 | Loss 2.779430
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:13	Epoch 0 | Batch 40/596 | Timestep 40 | LR 0.0001000000 | Loss 1.738882
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:16	Epoch 0 | Batch 50/596 | Timestep 50 | LR 0.0001000000 | Loss 1.265140
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:19	Epoch 0 | Batch 60/596 | Timestep 60 | LR 0.0001000000 | Loss 1.363964
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:22	Epoch 0 | Batch 70/596 | Timestep 70 | LR 0.0001000000 | Loss 1.141602
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:25	Epoch 0 | Batch 80/596 | Timestep 80 | LR 0.0001000000 | Loss 0.864536
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:27	Epoch 0 | Batch 90/596 | Timestep 90 | LR 0.0001000000 | Loss 0.746994
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:30	Epoch 0 | Batch 100/596 | Timestep 100 | LR 0.0001000000 | Loss 0.794192
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:33	Epoch 0 | Batch 110/596 | Timestep 110 | LR 0.0001000000 | Loss 0.820118
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:36	Epoch 0 | Batch 120/596 | Timestep 120 | LR 0.0001000000 | Loss 1.079705
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:39	Epoch 0 | Batch 130/596 | Timestep 130 | LR 0.0001000000 | Loss 0.734591
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:42	Epoch 0 | Batch 140/596 | Timestep 140 | LR 0.0001000000 | Loss 1.002975
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:45	Epoch 0 | Batch 150/596 | Timestep 150 | LR 0.0001000000 | Loss 0.724545
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:48	Epoch 0 | Batch 160/596 | Timestep 160 | LR 0.0001000000 | Loss 0.743712
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:50	Epoch 0 | Batch 170/596 | Timestep 170 | LR 0.0001000000 | Loss 0.738300
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:53	Epoch 0 | Batch 180/596 | Timestep 180 | LR 0.0001000000 | Loss 0.658900
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:56	Epoch 0 | Batch 190/596 | Timestep 190 | LR 0.0001000000 | Loss 0.472588
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:55:58	Epoch 0 | Batch 200/596 | Timestep 200 | LR 0.0001000000 | Loss 0.654829
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:01	Epoch 0 | Batch 210/596 | Timestep 210 | LR 0.0001000000 | Loss 0.319356
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:04	Epoch 0 | Batch 220/596 | Timestep 220 | LR 0.0001000000 | Loss 0.410193
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:07	Epoch 0 | Batch 230/596 | Timestep 230 | LR 0.0001000000 | Loss 0.514250
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:10	Epoch 0 | Batch 240/596 | Timestep 240 | LR 0.0001000000 | Loss 0.286531
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:13	Epoch 0 | Batch 250/596 | Timestep 250 | LR 0.0001000000 | Loss 0.256923
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:16	Epoch 0 | Batch 260/596 | Timestep 260 | LR 0.0001000000 | Loss 0.451287
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:19	Epoch 0 | Batch 270/596 | Timestep 270 | LR 0.0001000000 | Loss 0.547549
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:21	Epoch 0 | Batch 280/596 | Timestep 280 | LR 0.0001000000 | Loss 0.457184
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:24	Epoch 0 | Batch 290/596 | Timestep 290 | LR 0.0001000000 | Loss 0.228622
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:27	Epoch 0 | Batch 300/596 | Timestep 300 | LR 0.0001000000 | Loss 0.259809
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:30	Epoch 0 | Batch 310/596 | Timestep 310 | LR 0.0001000000 | Loss 0.340163
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:33	Epoch 0 | Batch 320/596 | Timestep 320 | LR 0.0001000000 | Loss 0.265537
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:36	Epoch 0 | Batch 330/596 | Timestep 330 | LR 0.0001000000 | Loss 0.224949
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:39	Epoch 0 | Batch 340/596 | Timestep 340 | LR 0.0001000000 | Loss 0.366845
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:41	Epoch 0 | Batch 350/596 | Timestep 350 | LR 0.0001000000 | Loss 0.202373
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:45	Epoch 0 | Batch 360/596 | Timestep 360 | LR 0.0001000000 | Loss 0.386474
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:48	Epoch 0 | Batch 370/596 | Timestep 370 | LR 0.0001000000 | Loss 0.157301
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:50	Epoch 0 | Batch 380/596 | Timestep 380 | LR 0.0001000000 | Loss 0.318466
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:54	Epoch 0 | Batch 390/596 | Timestep 390 | LR 0.0001000000 | Loss 0.194249
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:56:57	Epoch 0 | Batch 400/596 | Timestep 400 | LR 0.0001000000 | Loss 0.170169
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:00	Epoch 0 | Batch 410/596 | Timestep 410 | LR 0.0001000000 | Loss 0.203099
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:03	Epoch 0 | Batch 420/596 | Timestep 420 | LR 0.0001000000 | Loss 0.272385
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:06	Epoch 0 | Batch 430/596 | Timestep 430 | LR 0.0001000000 | Loss 0.239250
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:09	Epoch 0 | Batch 440/596 | Timestep 440 | LR 0.0001000000 | Loss 0.205990
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:11	Epoch 0 | Batch 450/596 | Timestep 450 | LR 0.0001000000 | Loss 0.241221
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:14	Epoch 0 | Batch 460/596 | Timestep 460 | LR 0.0001000000 | Loss 0.088355
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:16	Epoch 0 | Batch 470/596 | Timestep 470 | LR 0.0001000000 | Loss 0.198934
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:20	Epoch 0 | Batch 480/596 | Timestep 480 | LR 0.0001000000 | Loss 0.194671
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:22	Epoch 0 | Batch 490/596 | Timestep 490 | LR 0.0001000000 | Loss 0.101326
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:25	Epoch 0 | Batch 500/596 | Timestep 500 | LR 0.0001000000 | Loss 0.048360
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:28	Epoch 0 | Batch 510/596 | Timestep 510 | LR 0.0001000000 | Loss 0.133068
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:31	Epoch 0 | Batch 520/596 | Timestep 520 | LR 0.0001000000 | Loss 0.290084
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:34	Epoch 0 | Batch 530/596 | Timestep 530 | LR 0.0001000000 | Loss 0.263363
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:37	Epoch 0 | Batch 540/596 | Timestep 540 | LR 0.0001000000 | Loss 0.095232
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:40	Epoch 0 | Batch 550/596 | Timestep 550 | LR 0.0001000000 | Loss 0.154673
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:42	Epoch 0 | Batch 560/596 | Timestep 560 | LR 0.0001000000 | Loss 0.184897
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:45	Epoch 0 | Batch 570/596 | Timestep 570 | LR 0.0001000000 | Loss 0.225106
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:48	Epoch 0 | Batch 580/596 | Timestep 580 | LR 0.0001000000 | Loss 0.109136
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:51	Epoch 0 | Batch 590/596 | Timestep 590 | LR 0.0001000000 | Loss 0.206868
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:57:53	** Evaluating on validation dataset **
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO	root	Sun, 14 Apr 2024 20:58:32
#                    precision    recall  f1-score   support
#
#               AGE     0.7631    0.8857    0.8198       280
#             AWARD     0.3934    0.5217    0.4486        92
#              CITY     0.9152    0.8632    0.8884       475
#           COUNTRY     0.8650    0.9113    0.8876       970
#             CRIME     0.0000    0.0000    0.0000        83
#              DATE     0.8323    0.8411    0.8366       950
#           DISEASE     0.1070    0.3651    0.1655        63
#          DISTRICT     0.0000    0.0000    0.0000        60
#             EVENT     0.4310    0.6673    0.5237      1133
#          FACILITY     0.4626    0.3696    0.4109       184
#            FAMILY     0.0000    0.0000    0.0000        10
#          IDEOLOGY     0.5843    0.5909    0.5876        88
#          LANGUAGE     0.0000    0.0000    0.0000        23
#               LAW     0.1154    0.3793    0.1769        87
#          LOCATION     0.2453    0.1398    0.1781        93
#             MONEY     0.7073    0.7073    0.7073        41
#       NATIONALITY     0.8571    0.5294    0.6545       170
#            NUMBER     0.7920    0.8306    0.8109       431
#           ORDINAL     0.6957    0.8348    0.7589       230
#      ORGANIZATION     0.7392    0.8785    0.8029      1210
#           PENALTY     0.4286    0.2727    0.3333        22
#           PERCENT     0.8571    0.7059    0.7742        17
#            PERSON     0.9661    0.9254    0.9453      1877
#           PRODUCT     0.6154    0.2832    0.3879       113
#        PROFESSION     0.7095    0.8393    0.7689      1475
#          RELIGION     0.0000    0.0000    0.0000        44
# STATE_OR_PROVINCE     0.3818    0.5563    0.4528       151
#              TIME     0.5133    0.6517    0.5743        89
#       WORK_OF_ART     0.8158    0.7949    0.8052        78
#
#         micro avg     0.7049    0.7871    0.7437     10539
#         macro avg     0.5101    0.5291    0.5069     10539
#      weighted avg     0.7277    0.7871    0.7498     10539
#
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:58:53	Epoch 0 | Timestep 596 | Train Loss 1.004640 | Val Loss 0.189126 | F1 0.743713
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:58:53	** Validation improved, evaluating test data **
# INFO	root	Sun, 14 Apr 2024 20:59:02	Predictions written to ArabicNER/results/predictions.txt
# INFO	root	Sun, 14 Apr 2024 20:59:14
#                    precision    recall  f1-score   support
#
#               AGE     0.8276    0.8696    0.8481       138
#             AWARD     0.4240    0.5408    0.4753        98
#              CITY     0.8589    0.8661    0.8625       239
#           COUNTRY     0.8530    0.9075    0.8794       454
#             CRIME     0.0000    0.0000    0.0000        32
#              DATE     0.8528    0.8814    0.8669       506
#           DISEASE     0.2126    0.5400    0.3051        50
#          DISTRICT     0.0000    0.0000    0.0000        25
#             EVENT     0.3954    0.6359    0.4876       618
#          FACILITY     0.3276    0.3065    0.3167        62
#            FAMILY     0.0000    0.0000    0.0000        13
#          IDEOLOGY     0.6316    0.2927    0.4000        41
#          LANGUAGE     0.0000    0.0000    0.0000         8
#               LAW     0.0440    0.1750    0.0704        40
#          LOCATION     0.2857    0.0678    0.1096        59
#             MONEY     0.6744    0.6744    0.6744        43
#       NATIONALITY     0.8036    0.6818    0.7377        66
#            NUMBER     0.7952    0.7557    0.7749       221
#           ORDINAL     0.6519    0.8224    0.7273       107
#      ORGANIZATION     0.6434    0.7993    0.7129       553
#           PENALTY     0.5000    0.2143    0.3000        14
#           PERCENT     0.2000    0.1429    0.1667         7
#            PERSON     0.9348    0.9133    0.9239       957
#           PRODUCT     0.7143    0.2083    0.3226        48
#        PROFESSION     0.6429    0.7778    0.7039       648
#          RELIGION     0.0000    0.0000    0.0000        23
# STATE_OR_PROVINCE     0.5000    0.6161    0.5520       112
#              TIME     0.4340    0.4894    0.4600        47
#       WORK_OF_ART     0.7344    0.4845    0.5839        97
#
#         micro avg     0.6650    0.7514    0.7056      5326
#         macro avg     0.4808    0.4711    0.4573      5326
#      weighted avg     0.6918    0.7514    0.7119      5326
#
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:59:25	Epoch 0 | Timestep 596 | Test Loss 0.198237 | F1 0.705571
# INFO	arabiner.trainers.BaseTrainer	Sun, 14 Apr 2024 20:59:25	Saving checkpoint to ArabicNER/results/checkpoints/checkpoint_0.pt
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:59:53	Epoch 1 | Batch 4/596 | Timestep 600 | LR 0.0001000000 | Loss 0.144891
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:59:56	Epoch 1 | Batch 14/596 | Timestep 610 | LR 0.0001000000 | Loss 0.250987
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 20:59:59	Epoch 1 | Batch 24/596 | Timestep 620 | LR 0.0001000000 | Loss 0.087546
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:01	Epoch 1 | Batch 34/596 | Timestep 630 | LR 0.0001000000 | Loss 0.155225
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:04	Epoch 1 | Batch 44/596 | Timestep 640 | LR 0.0001000000 | Loss 0.138179
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:07	Epoch 1 | Batch 54/596 | Timestep 650 | LR 0.0001000000 | Loss 0.200946
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:10	Epoch 1 | Batch 64/596 | Timestep 660 | LR 0.0001000000 | Loss 0.148831
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:13	Epoch 1 | Batch 74/596 | Timestep 670 | LR 0.0001000000 | Loss 0.131948
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:16	Epoch 1 | Batch 84/596 | Timestep 680 | LR 0.0001000000 | Loss 0.149848
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:19	Epoch 1 | Batch 94/596 | Timestep 690 | LR 0.0001000000 | Loss 0.121202
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:22	Epoch 1 | Batch 104/596 | Timestep 700 | LR 0.0001000000 | Loss 0.166238
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:25	Epoch 1 | Batch 114/596 | Timestep 710 | LR 0.0001000000 | Loss 0.063194
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:27	Epoch 1 | Batch 124/596 | Timestep 720 | LR 0.0001000000 | Loss 0.155765
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:30	Epoch 1 | Batch 134/596 | Timestep 730 | LR 0.0001000000 | Loss 0.098903
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:33	Epoch 1 | Batch 144/596 | Timestep 740 | LR 0.0001000000 | Loss 0.113629
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:36	Epoch 1 | Batch 154/596 | Timestep 750 | LR 0.0001000000 | Loss 0.098110
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:40	Epoch 1 | Batch 164/596 | Timestep 760 | LR 0.0001000000 | Loss 0.126461
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:43	Epoch 1 | Batch 174/596 | Timestep 770 | LR 0.0001000000 | Loss 0.150074
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:46	Epoch 1 | Batch 184/596 | Timestep 780 | LR 0.0001000000 | Loss 0.149363
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:49	Epoch 1 | Batch 194/596 | Timestep 790 | LR 0.0001000000 | Loss 0.180893
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:52	Epoch 1 | Batch 204/596 | Timestep 800 | LR 0.0001000000 | Loss 0.169869
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:55	Epoch 1 | Batch 214/596 | Timestep 810 | LR 0.0001000000 | Loss 0.239018
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:00:58	Epoch 1 | Batch 224/596 | Timestep 820 | LR 0.0001000000 | Loss 0.153252
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:01	Epoch 1 | Batch 234/596 | Timestep 830 | LR 0.0001000000 | Loss 0.127270
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:04	Epoch 1 | Batch 244/596 | Timestep 840 | LR 0.0001000000 | Loss 0.173356
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:07	Epoch 1 | Batch 254/596 | Timestep 850 | LR 0.0001000000 | Loss 0.126228
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:09	Epoch 1 | Batch 264/596 | Timestep 860 | LR 0.0001000000 | Loss 0.096991
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:13	Epoch 1 | Batch 274/596 | Timestep 870 | LR 0.0001000000 | Loss 0.187244
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:16	Epoch 1 | Batch 284/596 | Timestep 880 | LR 0.0001000000 | Loss 0.071342
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:19	Epoch 1 | Batch 294/596 | Timestep 890 | LR 0.0001000000 | Loss 0.096510
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:21	Epoch 1 | Batch 304/596 | Timestep 900 | LR 0.0001000000 | Loss 0.103633
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:24	Epoch 1 | Batch 314/596 | Timestep 910 | LR 0.0001000000 | Loss 0.113189
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:27	Epoch 1 | Batch 324/596 | Timestep 920 | LR 0.0001000000 | Loss 0.209425
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:30	Epoch 1 | Batch 334/596 | Timestep 930 | LR 0.0001000000 | Loss 0.120875
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:33	Epoch 1 | Batch 344/596 | Timestep 940 | LR 0.0001000000 | Loss 0.146127
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:36	Epoch 1 | Batch 354/596 | Timestep 950 | LR 0.0001000000 | Loss 0.188539
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:39	Epoch 1 | Batch 364/596 | Timestep 960 | LR 0.0001000000 | Loss 0.202464
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:42	Epoch 1 | Batch 374/596 | Timestep 970 | LR 0.0001000000 | Loss 0.213546
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:44	Epoch 1 | Batch 384/596 | Timestep 980 | LR 0.0001000000 | Loss 0.041261
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:47	Epoch 1 | Batch 394/596 | Timestep 990 | LR 0.0001000000 | Loss 0.100969
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:50	Epoch 1 | Batch 404/596 | Timestep 1000 | LR 0.0001000000 | Loss 0.096925
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:53	Epoch 1 | Batch 414/596 | Timestep 1010 | LR 0.0001000000 | Loss 0.093141
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:56	Epoch 1 | Batch 424/596 | Timestep 1020 | LR 0.0001000000 | Loss 0.116183
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:01:59	Epoch 1 | Batch 434/596 | Timestep 1030 | LR 0.0001000000 | Loss 0.076103
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:02	Epoch 1 | Batch 444/596 | Timestep 1040 | LR 0.0001000000 | Loss 0.059899
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:05	Epoch 1 | Batch 454/596 | Timestep 1050 | LR 0.0001000000 | Loss 0.111059
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:09	Epoch 1 | Batch 464/596 | Timestep 1060 | LR 0.0001000000 | Loss 0.168268
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:12	Epoch 1 | Batch 474/596 | Timestep 1070 | LR 0.0001000000 | Loss 0.093844
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:15	Epoch 1 | Batch 484/596 | Timestep 1080 | LR 0.0001000000 | Loss 0.061136
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:18	Epoch 1 | Batch 494/596 | Timestep 1090 | LR 0.0001000000 | Loss 0.074127
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:20	Epoch 1 | Batch 504/596 | Timestep 1100 | LR 0.0001000000 | Loss 0.070700
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:23	Epoch 1 | Batch 514/596 | Timestep 1110 | LR 0.0001000000 | Loss 0.044935
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:26	Epoch 1 | Batch 524/596 | Timestep 1120 | LR 0.0001000000 | Loss 0.077918
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:29	Epoch 1 | Batch 534/596 | Timestep 1130 | LR 0.0001000000 | Loss 0.172644
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:32	Epoch 1 | Batch 544/596 | Timestep 1140 | LR 0.0001000000 | Loss 0.071293
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:34	Epoch 1 | Batch 554/596 | Timestep 1150 | LR 0.0001000000 | Loss 0.089668
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:37	Epoch 1 | Batch 564/596 | Timestep 1160 | LR 0.0001000000 | Loss 0.054769
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:40	Epoch 1 | Batch 574/596 | Timestep 1170 | LR 0.0001000000 | Loss 0.083456
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:43	Epoch 1 | Batch 584/596 | Timestep 1180 | LR 0.0001000000 | Loss 0.130384
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:46	Epoch 1 | Batch 594/596 | Timestep 1190 | LR 0.0001000000 | Loss 0.052224
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:02:47	** Evaluating on validation dataset **
# INFO	root	Sun, 14 Apr 2024 21:03:26
#                    precision    recall  f1-score   support
#
#               AGE     0.8754    0.9536    0.9128       280
#             AWARD     0.4545    0.7609    0.5691        92
#              CITY     0.8607    0.9368    0.8972       475
#           COUNTRY     0.9732    0.9722    0.9727       970
#             CRIME     0.5417    0.6265    0.5810        83
#              DATE     0.8482    0.8821    0.8648       950
#           DISEASE     0.5867    0.6984    0.6377        63
#          DISTRICT     0.6800    0.5667    0.6182        60
#             EVENT     0.5997    0.7405    0.6627      1133
#          FACILITY     0.5074    0.5598    0.5323       184
#            FAMILY     0.0000    0.0000    0.0000        10
#          IDEOLOGY     0.6733    0.7727    0.7196        88
#          LANGUAGE     0.9565    0.9565    0.9565        23
#               LAW     0.5159    0.7471    0.6103        87
#          LOCATION     0.6058    0.6774    0.6396        93
#             MONEY     0.8000    0.7805    0.7901        41
#       NATIONALITY     0.7068    0.7941    0.7479       170
#            NUMBER     0.8961    0.9002    0.8981       431
#           ORDINAL     0.8382    0.8783    0.8577       230
#      ORGANIZATION     0.8280    0.8711    0.8490      1210
#           PENALTY     0.5833    0.6364    0.6087        22
#           PERCENT     1.0000    1.0000    1.0000        17
#            PERSON     0.9839    0.9739    0.9788      1877
#           PRODUCT     0.7714    0.7168    0.7431       113
#        PROFESSION     0.7978    0.8936    0.8430      1475
#          RELIGION     0.9000    0.8182    0.8571        44
# STATE_OR_PROVINCE     0.8693    0.8808    0.8750       151
#              TIME     0.6449    0.7753    0.7041        89
#       WORK_OF_ART     0.8272    0.8590    0.8428        78
#
#         micro avg     0.8147    0.8755    0.8440     10539
#         macro avg     0.7285    0.7803    0.7507     10539
#      weighted avg     0.8246    0.8755    0.8479     10539
#
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:03:46	Epoch 1 | Timestep 1192 | Train Loss 0.114468 | Val Loss 0.101789 | F1 0.844036
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:03:46	** Validation improved, evaluating test data **
# INFO	root	Sun, 14 Apr 2024 21:03:55	Predictions written to ArabicNER/results/predictions.txt
# INFO	root	Sun, 14 Apr 2024 21:04:08
#                    precision    recall  f1-score   support
#
#               AGE     0.8451    0.8696    0.8571       138
#             AWARD     0.5440    0.6939    0.6099        98
#              CITY     0.8345    0.9707    0.8975       239
#           COUNTRY     0.9578    0.9493    0.9535       454
#             CRIME     0.3226    0.6250    0.4255        32
#              DATE     0.8635    0.9249    0.8931       506
#           DISEASE     0.6604    0.7000    0.6796        50
#          DISTRICT     0.8148    0.8800    0.8462        25
#             EVENT     0.4760    0.6246    0.5402       618
#          FACILITY     0.4828    0.4516    0.4667        62
#            FAMILY     0.0000    0.0000    0.0000        13
#          IDEOLOGY     0.6923    0.4390    0.5373        41
#          LANGUAGE     0.4545    0.6250    0.5263         8
#               LAW     0.2877    0.5250    0.3717        40
#          LOCATION     0.7872    0.6271    0.6981        59
#             MONEY     0.8140    0.8140    0.8140        43
#       NATIONALITY     0.6316    0.9091    0.7453        66
#            NUMBER     0.8702    0.8190    0.8438       221
#           ORDINAL     0.7589    0.7944    0.7763       107
#      ORGANIZATION     0.7370    0.7957    0.7652       553
#           PENALTY     0.5333    0.5714    0.5517        14
#           PERCENT     0.6667    0.5714    0.6154         7
#            PERSON     0.9443    0.9561    0.9502       957
#           PRODUCT     0.6875    0.6875    0.6875        48
#        PROFESSION     0.7286    0.8287    0.7755       648
#          RELIGION     0.8947    0.7391    0.8095        23
# STATE_OR_PROVINCE     0.8319    0.8393    0.8356       112
#              TIME     0.6042    0.6170    0.6105        47
#       WORK_OF_ART     0.7342    0.5979    0.6591        97
#
#         micro avg     0.7572    0.8237    0.7890      5326
#         macro avg     0.6710    0.7050    0.6808      5326
#      weighted avg     0.7719    0.8237    0.7942      5326
#
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:04:19	Epoch 1 | Timestep 1192 | Test Loss 0.137186 | F1 0.789029
# INFO	arabiner.trainers.BaseTrainer	Sun, 14 Apr 2024 21:04:19	Saving checkpoint to ArabicNER/results/checkpoints/checkpoint_1.pt
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:04:46	Epoch 2 | Batch 8/596 | Timestep 1200 | LR 0.0001000000 | Loss 0.051087
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:04:49	Epoch 2 | Batch 18/596 | Timestep 1210 | LR 0.0001000000 | Loss 0.059701
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:04:52	Epoch 2 | Batch 28/596 | Timestep 1220 | LR 0.0001000000 | Loss 0.030050
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:04:55	Epoch 2 | Batch 38/596 | Timestep 1230 | LR 0.0001000000 | Loss 0.034319
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:04:58	Epoch 2 | Batch 48/596 | Timestep 1240 | LR 0.0001000000 | Loss 0.069409
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:01	Epoch 2 | Batch 58/596 | Timestep 1250 | LR 0.0001000000 | Loss 0.078668
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:05	Epoch 2 | Batch 68/596 | Timestep 1260 | LR 0.0001000000 | Loss 0.080476
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:07	Epoch 2 | Batch 78/596 | Timestep 1270 | LR 0.0001000000 | Loss 0.028552
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:10	Epoch 2 | Batch 88/596 | Timestep 1280 | LR 0.0001000000 | Loss 0.132127
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:13	Epoch 2 | Batch 98/596 | Timestep 1290 | LR 0.0001000000 | Loss 0.056437
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:17	Epoch 2 | Batch 108/596 | Timestep 1300 | LR 0.0001000000 | Loss 0.024181
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:20	Epoch 2 | Batch 118/596 | Timestep 1310 | LR 0.0001000000 | Loss 0.044043
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:23	Epoch 2 | Batch 128/596 | Timestep 1320 | LR 0.0001000000 | Loss 0.052373
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:25	Epoch 2 | Batch 138/596 | Timestep 1330 | LR 0.0001000000 | Loss 0.076769
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:29	Epoch 2 | Batch 148/596 | Timestep 1340 | LR 0.0001000000 | Loss 0.033646
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:31	Epoch 2 | Batch 158/596 | Timestep 1350 | LR 0.0001000000 | Loss 0.024026
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:34	Epoch 2 | Batch 168/596 | Timestep 1360 | LR 0.0001000000 | Loss 0.086003
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:37	Epoch 2 | Batch 178/596 | Timestep 1370 | LR 0.0001000000 | Loss 0.032978
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:40	Epoch 2 | Batch 188/596 | Timestep 1380 | LR 0.0001000000 | Loss 0.061262
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:43	Epoch 2 | Batch 198/596 | Timestep 1390 | LR 0.0001000000 | Loss 0.086465
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:46	Epoch 2 | Batch 208/596 | Timestep 1400 | LR 0.0001000000 | Loss 0.058157
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:49	Epoch 2 | Batch 218/596 | Timestep 1410 | LR 0.0001000000 | Loss 0.039522
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:51	Epoch 2 | Batch 228/596 | Timestep 1420 | LR 0.0001000000 | Loss 0.056686
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:54	Epoch 2 | Batch 238/596 | Timestep 1430 | LR 0.0001000000 | Loss 0.095601
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:05:57	Epoch 2 | Batch 248/596 | Timestep 1440 | LR 0.0001000000 | Loss 0.081282
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:01	Epoch 2 | Batch 258/596 | Timestep 1450 | LR 0.0001000000 | Loss 0.043793
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:04	Epoch 2 | Batch 268/596 | Timestep 1460 | LR 0.0001000000 | Loss 0.051281
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:06	Epoch 2 | Batch 278/596 | Timestep 1470 | LR 0.0001000000 | Loss 0.105164
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:10	Epoch 2 | Batch 288/596 | Timestep 1480 | LR 0.0001000000 | Loss 0.095903
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:12	Epoch 2 | Batch 298/596 | Timestep 1490 | LR 0.0001000000 | Loss 0.062379
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:16	Epoch 2 | Batch 308/596 | Timestep 1500 | LR 0.0001000000 | Loss 0.050627
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:18	Epoch 2 | Batch 318/596 | Timestep 1510 | LR 0.0001000000 | Loss 0.056137
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:21	Epoch 2 | Batch 328/596 | Timestep 1520 | LR 0.0001000000 | Loss 0.078475
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:24	Epoch 2 | Batch 338/596 | Timestep 1530 | LR 0.0001000000 | Loss 0.036655
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:27	Epoch 2 | Batch 348/596 | Timestep 1540 | LR 0.0001000000 | Loss 0.068926
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:30	Epoch 2 | Batch 358/596 | Timestep 1550 | LR 0.0001000000 | Loss 0.072772
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:33	Epoch 2 | Batch 368/596 | Timestep 1560 | LR 0.0001000000 | Loss 0.081471
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:36	Epoch 2 | Batch 378/596 | Timestep 1570 | LR 0.0001000000 | Loss 0.016941
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:38	Epoch 2 | Batch 388/596 | Timestep 1580 | LR 0.0001000000 | Loss 0.081185
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:41	Epoch 2 | Batch 398/596 | Timestep 1590 | LR 0.0001000000 | Loss 0.038708
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:44	Epoch 2 | Batch 408/596 | Timestep 1600 | LR 0.0001000000 | Loss 0.036021
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:47	Epoch 2 | Batch 418/596 | Timestep 1610 | LR 0.0001000000 | Loss 0.065237
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:49	Epoch 2 | Batch 428/596 | Timestep 1620 | LR 0.0001000000 | Loss 0.086374
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:52	Epoch 2 | Batch 438/596 | Timestep 1630 | LR 0.0001000000 | Loss 0.046408
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:57	Epoch 2 | Batch 448/596 | Timestep 1640 | LR 0.0001000000 | Loss 0.029128
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:06:59	Epoch 2 | Batch 458/596 | Timestep 1650 | LR 0.0001000000 | Loss 0.047003
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:02	Epoch 2 | Batch 468/596 | Timestep 1660 | LR 0.0001000000 | Loss 0.049795
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:05	Epoch 2 | Batch 478/596 | Timestep 1670 | LR 0.0001000000 | Loss 0.113853
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:08	Epoch 2 | Batch 488/596 | Timestep 1680 | LR 0.0001000000 | Loss 0.130720
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:11	Epoch 2 | Batch 498/596 | Timestep 1690 | LR 0.0001000000 | Loss 0.080156
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:13	Epoch 2 | Batch 508/596 | Timestep 1700 | LR 0.0001000000 | Loss 0.045163
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:17	Epoch 2 | Batch 518/596 | Timestep 1710 | LR 0.0001000000 | Loss 0.019226
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:20	Epoch 2 | Batch 528/596 | Timestep 1720 | LR 0.0001000000 | Loss 0.055084
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:22	Epoch 2 | Batch 538/596 | Timestep 1730 | LR 0.0001000000 | Loss 0.068037
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:25	Epoch 2 | Batch 548/596 | Timestep 1740 | LR 0.0001000000 | Loss 0.055150
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:28	Epoch 2 | Batch 558/596 | Timestep 1750 | LR 0.0001000000 | Loss 0.052523
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:31	Epoch 2 | Batch 568/596 | Timestep 1760 | LR 0.0001000000 | Loss 0.029769
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:34	Epoch 2 | Batch 578/596 | Timestep 1770 | LR 0.0001000000 | Loss 0.020126
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:37	Epoch 2 | Batch 588/596 | Timestep 1780 | LR 0.0001000000 | Loss 0.064132
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:07:39	** Evaluating on validation dataset **
# INFO	root	Sun, 14 Apr 2024 21:08:18
#                    precision    recall  f1-score   support
#
#               AGE     0.8689    0.9464    0.9060       280
#             AWARD     0.5414    0.7826    0.6400        92
#              CITY     0.8509    0.9495    0.8975       475
#           COUNTRY     0.9424    0.9784    0.9600       970
#             CRIME     0.5378    0.7711    0.6337        83
#              DATE     0.8966    0.8947    0.8957       950
#           DISEASE     0.7385    0.7619    0.7500        63
#          DISTRICT     0.6508    0.6833    0.6667        60
#             EVENT     0.6803    0.7776    0.7257      1133
#          FACILITY     0.7189    0.7228    0.7209       184
#            FAMILY     0.0909    0.1000    0.0952        10
#          IDEOLOGY     0.7527    0.7955    0.7735        88
#          LANGUAGE     0.9565    0.9565    0.9565        23
#               LAW     0.4504    0.6782    0.5413        87
#          LOCATION     0.7024    0.6344    0.6667        93
#             MONEY     0.8140    0.8537    0.8333        41
#       NATIONALITY     0.8095    0.7000    0.7508       170
#            NUMBER     0.9262    0.9026    0.9142       431
#           ORDINAL     0.8577    0.8913    0.8742       230
#      ORGANIZATION     0.8369    0.9372    0.8842      1210
#           PENALTY     0.8462    0.5000    0.6286        22
#           PERCENT     1.0000    1.0000    1.0000        17
#            PERSON     0.9721    0.9830    0.9775      1877
#           PRODUCT     0.9072    0.7788    0.8381       113
#        PROFESSION     0.8804    0.9085    0.8942      1475
#          RELIGION     0.8113    0.9773    0.8866        44
# STATE_OR_PROVINCE     0.9407    0.8411    0.8881       151
#              TIME     0.7634    0.7978    0.7802        89
#       WORK_OF_ART     0.9028    0.8333    0.8667        78
#
#         micro avg     0.8520    0.8970    0.8740     10539
#         macro avg     0.7810    0.8047    0.7878     10539
#      weighted avg     0.8585    0.8970    0.8760     10539
#
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:08:39	Epoch 2 | Timestep 1788 | Train Loss 0.062256 | Val Loss 0.096120 | F1 0.873954
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:08:39	** Validation improved, evaluating test data **
# INFO	root	Sun, 14 Apr 2024 21:08:48	Predictions written to ArabicNER/results/predictions.txt
# INFO	root	Sun, 14 Apr 2024 21:09:00
#                    precision    recall  f1-score   support
#
#               AGE     0.8803    0.9058    0.8929       138
#             AWARD     0.6387    0.7755    0.7005        98
#              CITY     0.8262    0.9749    0.8944       239
#           COUNTRY     0.9213    0.9537    0.9372       454
#             CRIME     0.3077    0.7500    0.4364        32
#              DATE     0.8820    0.9012    0.8915       506
#           DISEASE     0.6610    0.7800    0.7156        50
#          DISTRICT     0.5882    0.8000    0.6780        25
#             EVENT     0.5213    0.6521    0.5794       618
#          FACILITY     0.5156    0.5323    0.5238        62
#            FAMILY     0.6667    0.1538    0.2500        13
#          IDEOLOGY     0.8077    0.5122    0.6269        41
#          LANGUAGE     0.6250    0.6250    0.6250         8
#               LAW     0.2763    0.5250    0.3621        40
#          LOCATION     0.7105    0.4576    0.5567        59
#             MONEY     0.7556    0.7907    0.7727        43
#       NATIONALITY     0.7143    0.8333    0.7692        66
#            NUMBER     0.8786    0.8190    0.8478       221
#           ORDINAL     0.7719    0.8224    0.7964       107
#      ORGANIZATION     0.7136    0.8698    0.7840       553
#           PENALTY     0.3750    0.2143    0.2727        14
#           PERCENT     0.5714    0.5714    0.5714         7
#            PERSON     0.9286    0.9645    0.9462       957
#           PRODUCT     0.7561    0.6458    0.6966        48
#        PROFESSION     0.7638    0.8086    0.7856       648
#          RELIGION     0.7727    0.7391    0.7556        23
# STATE_OR_PROVINCE     0.8235    0.7500    0.7850       112
#              TIME     0.7111    0.6809    0.6957        47
#       WORK_OF_ART     0.8169    0.5979    0.6905        97
#
#         micro avg     0.7668    0.8323    0.7982      5326
#         macro avg     0.6959    0.7037    0.6841      5326
#      weighted avg     0.7812    0.8323    0.8020      5326
#
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:09:11	Epoch 2 | Timestep 1788 | Test Loss 0.151174 | F1 0.798235
# INFO	arabiner.trainers.BaseTrainer	Sun, 14 Apr 2024 21:09:11	Saving checkpoint to ArabicNER/results/checkpoints/checkpoint_2.pt
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:09:36	Epoch 3 | Batch 2/596 | Timestep 1790 | LR 0.0001000000 | Loss 0.025450
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:09:39	Epoch 3 | Batch 12/596 | Timestep 1800 | LR 0.0001000000 | Loss 0.020959
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:09:42	Epoch 3 | Batch 22/596 | Timestep 1810 | LR 0.0001000000 | Loss 0.032995
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:09:45	Epoch 3 | Batch 32/596 | Timestep 1820 | LR 0.0001000000 | Loss 0.021196
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:09:48	Epoch 3 | Batch 42/596 | Timestep 1830 | LR 0.0001000000 | Loss 0.049488
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:09:51	Epoch 3 | Batch 52/596 | Timestep 1840 | LR 0.0001000000 | Loss 0.033403
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:09:54	Epoch 3 | Batch 62/596 | Timestep 1850 | LR 0.0001000000 | Loss 0.063813
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:09:58	Epoch 3 | Batch 72/596 | Timestep 1860 | LR 0.0001000000 | Loss 0.054463
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:01	Epoch 3 | Batch 82/596 | Timestep 1870 | LR 0.0001000000 | Loss 0.036872
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:04	Epoch 3 | Batch 92/596 | Timestep 1880 | LR 0.0001000000 | Loss 0.036769
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:07	Epoch 3 | Batch 102/596 | Timestep 1890 | LR 0.0001000000 | Loss 0.034106
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:11	Epoch 3 | Batch 112/596 | Timestep 1900 | LR 0.0001000000 | Loss 0.042893
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:13	Epoch 3 | Batch 122/596 | Timestep 1910 | LR 0.0001000000 | Loss 0.033784
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:16	Epoch 3 | Batch 132/596 | Timestep 1920 | LR 0.0001000000 | Loss 0.031276
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:18	Epoch 3 | Batch 142/596 | Timestep 1930 | LR 0.0001000000 | Loss 0.047563
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:22	Epoch 3 | Batch 152/596 | Timestep 1940 | LR 0.0001000000 | Loss 0.049506
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:25	Epoch 3 | Batch 162/596 | Timestep 1950 | LR 0.0001000000 | Loss 0.038680
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:27	Epoch 3 | Batch 172/596 | Timestep 1960 | LR 0.0001000000 | Loss 0.019120
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:30	Epoch 3 | Batch 182/596 | Timestep 1970 | LR 0.0001000000 | Loss 0.029170
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:34	Epoch 3 | Batch 192/596 | Timestep 1980 | LR 0.0001000000 | Loss 0.060945
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:36	Epoch 3 | Batch 202/596 | Timestep 1990 | LR 0.0001000000 | Loss 0.080611
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:39	Epoch 3 | Batch 212/596 | Timestep 2000 | LR 0.0001000000 | Loss 0.043475
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:41	Epoch 3 | Batch 222/596 | Timestep 2010 | LR 0.0001000000 | Loss 0.049877
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:44	Epoch 3 | Batch 232/596 | Timestep 2020 | LR 0.0001000000 | Loss 0.043748
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:47	Epoch 3 | Batch 242/596 | Timestep 2030 | LR 0.0001000000 | Loss 0.021264
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:50	Epoch 3 | Batch 252/596 | Timestep 2040 | LR 0.0001000000 | Loss 0.037285
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:53	Epoch 3 | Batch 262/596 | Timestep 2050 | LR 0.0001000000 | Loss 0.065907
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:56	Epoch 3 | Batch 272/596 | Timestep 2060 | LR 0.0001000000 | Loss 0.044577
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:10:58	Epoch 3 | Batch 282/596 | Timestep 2070 | LR 0.0001000000 | Loss 0.052619
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:01	Epoch 3 | Batch 292/596 | Timestep 2080 | LR 0.0001000000 | Loss 0.053676
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:04	Epoch 3 | Batch 302/596 | Timestep 2090 | LR 0.0001000000 | Loss 0.065462
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:07	Epoch 3 | Batch 312/596 | Timestep 2100 | LR 0.0001000000 | Loss 0.052037
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:10	Epoch 3 | Batch 322/596 | Timestep 2110 | LR 0.0001000000 | Loss 0.025188
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:13	Epoch 3 | Batch 332/596 | Timestep 2120 | LR 0.0001000000 | Loss 0.051972
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:16	Epoch 3 | Batch 342/596 | Timestep 2130 | LR 0.0001000000 | Loss 0.043460
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:18	Epoch 3 | Batch 352/596 | Timestep 2140 | LR 0.0001000000 | Loss 0.036393
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:21	Epoch 3 | Batch 362/596 | Timestep 2150 | LR 0.0001000000 | Loss 0.030248
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:24	Epoch 3 | Batch 372/596 | Timestep 2160 | LR 0.0001000000 | Loss 0.062485
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:27	Epoch 3 | Batch 382/596 | Timestep 2170 | LR 0.0001000000 | Loss 0.059230
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:30	Epoch 3 | Batch 392/596 | Timestep 2180 | LR 0.0001000000 | Loss 0.042913
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:11:32	Epoch 3 | Batch 402/596 | Timestep 2190 | LR 0.0001000000 | Loss 0.040772
# ...
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:31:59	Epoch 8 | Batch 392/596 | Timestep 5160 | LR 0.0001000000 | Loss 0.037814
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:02	Epoch 8 | Batch 402/596 | Timestep 5170 | LR 0.0001000000 | Loss 0.026574
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:05	Epoch 8 | Batch 412/596 | Timestep 5180 | LR 0.0001000000 | Loss 0.008998
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:09	Epoch 8 | Batch 422/596 | Timestep 5190 | LR 0.0001000000 | Loss 0.008076
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:11	Epoch 8 | Batch 432/596 | Timestep 5200 | LR 0.0001000000 | Loss 0.004218
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:14	Epoch 8 | Batch 442/596 | Timestep 5210 | LR 0.0001000000 | Loss 0.009555
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:17	Epoch 8 | Batch 452/596 | Timestep 5220 | LR 0.0001000000 | Loss 0.023160
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:20	Epoch 8 | Batch 462/596 | Timestep 5230 | LR 0.0001000000 | Loss 0.048866
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:23	Epoch 8 | Batch 472/596 | Timestep 5240 | LR 0.0001000000 | Loss 0.009739
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:26	Epoch 8 | Batch 482/596 | Timestep 5250 | LR 0.0001000000 | Loss 0.022009
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:29	Epoch 8 | Batch 492/596 | Timestep 5260 | LR 0.0001000000 | Loss 0.022674
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:32	Epoch 8 | Batch 502/596 | Timestep 5270 | LR 0.0001000000 | Loss 0.035269
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:35	Epoch 8 | Batch 512/596 | Timestep 5280 | LR 0.0001000000 | Loss 0.033696
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:38	Epoch 8 | Batch 522/596 | Timestep 5290 | LR 0.0001000000 | Loss 0.036014
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:41	Epoch 8 | Batch 532/596 | Timestep 5300 | LR 0.0001000000 | Loss 0.029516
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:44	Epoch 8 | Batch 542/596 | Timestep 5310 | LR 0.0001000000 | Loss 0.009427
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:46	Epoch 8 | Batch 552/596 | Timestep 5320 | LR 0.0001000000 | Loss 0.013259
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:49	Epoch 8 | Batch 562/596 | Timestep 5330 | LR 0.0001000000 | Loss 0.012508
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:52	Epoch 8 | Batch 572/596 | Timestep 5340 | LR 0.0001000000 | Loss 0.015168
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:55	Epoch 8 | Batch 582/596 | Timestep 5350 | LR 0.0001000000 | Loss 0.024331
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:58	Epoch 8 | Batch 592/596 | Timestep 5360 | LR 0.0001000000 | Loss 0.008338
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:32:59	** Evaluating on validation dataset **
# INFO	root	Sun, 14 Apr 2024 21:33:38
#                    precision    recall  f1-score   support
#
#               AGE     0.9181    0.9214    0.9198       280
#             AWARD     0.6174    0.7717    0.6860        92
#              CITY     0.9516    0.9516    0.9516       475
#           COUNTRY     0.9692    0.9722    0.9707       970
#             CRIME     0.7176    0.7349    0.7262        83
#              DATE     0.9057    0.9200    0.9128       950
#           DISEASE     0.7843    0.6349    0.7018        63
#          DISTRICT     0.7049    0.7167    0.7107        60
#             EVENT     0.7432    0.7970    0.7692      1133
#          FACILITY     0.7917    0.8261    0.8085       184
#            FAMILY     0.5625    0.9000    0.6923        10
#          IDEOLOGY     0.9213    0.9318    0.9266        88
#          LANGUAGE     1.0000    0.9565    0.9778        23
#               LAW     0.5232    0.9080    0.6639        87
#          LOCATION     0.6964    0.8387    0.7610        93
#             MONEY     0.8372    0.8780    0.8571        41
#       NATIONALITY     0.8954    0.8059    0.8483       170
#            NUMBER     0.9245    0.9374    0.9309       431
#           ORDINAL     0.9518    0.9435    0.9476       230
#      ORGANIZATION     0.8765    0.9264    0.9008      1210
#           PENALTY     0.2667    0.1818    0.2162        22
#           PERCENT     0.7895    0.8824    0.8333        17
#            PERSON     0.9639    0.9803    0.9720      1877
#           PRODUCT     0.9540    0.7345    0.8300       113
#        PROFESSION     0.8718    0.9173    0.8940      1475
#          RELIGION     0.8302    1.0000    0.9072        44
# STATE_OR_PROVINCE     0.9103    0.8742    0.8919       151
#              TIME     0.6882    0.7191    0.7033        89
#       WORK_OF_ART     0.6932    0.7821    0.7349        78
#
#         micro avg     0.8784    0.9088    0.8933     10539
#         macro avg     0.8021    0.8395    0.8154     10539
#      weighted avg     0.8826    0.9088    0.8945     10539
#
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:33:58	Epoch 8 | Timestep 5364 | Train Loss 0.026014 | Val Loss 0.104173 | F1 0.893345
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:01	Epoch 9 | Batch 6/596 | Timestep 5370 | LR 0.0001000000 | Loss 0.007644
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:05	Epoch 9 | Batch 16/596 | Timestep 5380 | LR 0.0001000000 | Loss 0.010486
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:07	Epoch 9 | Batch 26/596 | Timestep 5390 | LR 0.0001000000 | Loss 0.015297
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:10	Epoch 9 | Batch 36/596 | Timestep 5400 | LR 0.0001000000 | Loss 0.030387
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:14	Epoch 9 | Batch 46/596 | Timestep 5410 | LR 0.0001000000 | Loss 0.009525
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:17	Epoch 9 | Batch 56/596 | Timestep 5420 | LR 0.0001000000 | Loss 0.021145
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:20	Epoch 9 | Batch 66/596 | Timestep 5430 | LR 0.0001000000 | Loss 0.007512
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:22	Epoch 9 | Batch 76/596 | Timestep 5440 | LR 0.0001000000 | Loss 0.002575
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:25	Epoch 9 | Batch 86/596 | Timestep 5450 | LR 0.0001000000 | Loss 0.008261
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:28	Epoch 9 | Batch 96/596 | Timestep 5460 | LR 0.0001000000 | Loss 0.008064
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:31	Epoch 9 | Batch 106/596 | Timestep 5470 | LR 0.0001000000 | Loss 0.013416
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:34	Epoch 9 | Batch 116/596 | Timestep 5480 | LR 0.0001000000 | Loss 0.014495
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:37	Epoch 9 | Batch 126/596 | Timestep 5490 | LR 0.0001000000 | Loss 0.014046
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:40	Epoch 9 | Batch 136/596 | Timestep 5500 | LR 0.0001000000 | Loss 0.040511
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:43	Epoch 9 | Batch 146/596 | Timestep 5510 | LR 0.0001000000 | Loss 0.008245
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:46	Epoch 9 | Batch 156/596 | Timestep 5520 | LR 0.0001000000 | Loss 0.025395
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:49	Epoch 9 | Batch 166/596 | Timestep 5530 | LR 0.0001000000 | Loss 0.037680
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:52	Epoch 9 | Batch 176/596 | Timestep 5540 | LR 0.0001000000 | Loss 0.017813
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:55	Epoch 9 | Batch 186/596 | Timestep 5550 | LR 0.0001000000 | Loss 0.025577
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:34:57	Epoch 9 | Batch 196/596 | Timestep 5560 | LR 0.0001000000 | Loss 0.004870
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:00	Epoch 9 | Batch 206/596 | Timestep 5570 | LR 0.0001000000 | Loss 0.008000
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:03	Epoch 9 | Batch 216/596 | Timestep 5580 | LR 0.0001000000 | Loss 0.012325
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:06	Epoch 9 | Batch 226/596 | Timestep 5590 | LR 0.0001000000 | Loss 0.027906
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:09	Epoch 9 | Batch 236/596 | Timestep 5600 | LR 0.0001000000 | Loss 0.004228
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:11	Epoch 9 | Batch 246/596 | Timestep 5610 | LR 0.0001000000 | Loss 0.010931
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:14	Epoch 9 | Batch 256/596 | Timestep 5620 | LR 0.0001000000 | Loss 0.027155
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:17	Epoch 9 | Batch 266/596 | Timestep 5630 | LR 0.0001000000 | Loss 0.010421
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:20	Epoch 9 | Batch 276/596 | Timestep 5640 | LR 0.0001000000 | Loss 0.105728
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:23	Epoch 9 | Batch 286/596 | Timestep 5650 | LR 0.0001000000 | Loss 0.033866
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:25	Epoch 9 | Batch 296/596 | Timestep 5660 | LR 0.0001000000 | Loss 0.040537
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:29	Epoch 9 | Batch 306/596 | Timestep 5670 | LR 0.0001000000 | Loss 0.055215
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:32	Epoch 9 | Batch 316/596 | Timestep 5680 | LR 0.0001000000 | Loss 0.027244
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:34	Epoch 9 | Batch 326/596 | Timestep 5690 | LR 0.0001000000 | Loss 0.010848
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:37	Epoch 9 | Batch 336/596 | Timestep 5700 | LR 0.0001000000 | Loss 0.012905
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:40	Epoch 9 | Batch 346/596 | Timestep 5710 | LR 0.0001000000 | Loss 0.024655
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:43	Epoch 9 | Batch 356/596 | Timestep 5720 | LR 0.0001000000 | Loss 0.016866
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:46	Epoch 9 | Batch 366/596 | Timestep 5730 | LR 0.0001000000 | Loss 0.167964
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:49	Epoch 9 | Batch 376/596 | Timestep 5740 | LR 0.0001000000 | Loss 0.014080
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:52	Epoch 9 | Batch 386/596 | Timestep 5750 | LR 0.0001000000 | Loss 0.028658
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:55	Epoch 9 | Batch 396/596 | Timestep 5760 | LR 0.0001000000 | Loss 0.025427
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:35:58	Epoch 9 | Batch 406/596 | Timestep 5770 | LR 0.0001000000 | Loss 0.017150
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:01	Epoch 9 | Batch 416/596 | Timestep 5780 | LR 0.0001000000 | Loss 0.006450
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:04	Epoch 9 | Batch 426/596 | Timestep 5790 | LR 0.0001000000 | Loss 0.026197
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:07	Epoch 9 | Batch 436/596 | Timestep 5800 | LR 0.0001000000 | Loss 0.008796
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:10	Epoch 9 | Batch 446/596 | Timestep 5810 | LR 0.0001000000 | Loss 0.005509
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:13	Epoch 9 | Batch 456/596 | Timestep 5820 | LR 0.0001000000 | Loss 0.006654
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:16	Epoch 9 | Batch 466/596 | Timestep 5830 | LR 0.0001000000 | Loss 0.017784
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:19	Epoch 9 | Batch 476/596 | Timestep 5840 | LR 0.0001000000 | Loss 0.014651
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:22	Epoch 9 | Batch 486/596 | Timestep 5850 | LR 0.0001000000 | Loss 0.040105
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:25	Epoch 9 | Batch 496/596 | Timestep 5860 | LR 0.0001000000 | Loss 0.023024
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:28	Epoch 9 | Batch 506/596 | Timestep 5870 | LR 0.0001000000 | Loss 0.014021
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:31	Epoch 9 | Batch 516/596 | Timestep 5880 | LR 0.0001000000 | Loss 0.006819
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:33	Epoch 9 | Batch 526/596 | Timestep 5890 | LR 0.0001000000 | Loss 0.016165
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:36	Epoch 9 | Batch 536/596 | Timestep 5900 | LR 0.0001000000 | Loss 0.015943
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:39	Epoch 9 | Batch 546/596 | Timestep 5910 | LR 0.0001000000 | Loss 0.023553
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:42	Epoch 9 | Batch 556/596 | Timestep 5920 | LR 0.0001000000 | Loss 0.022707
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:45	Epoch 9 | Batch 566/596 | Timestep 5930 | LR 0.0001000000 | Loss 0.023326
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:48	Epoch 9 | Batch 576/596 | Timestep 5940 | LR 0.0001000000 | Loss 0.016403
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:50	Epoch 9 | Batch 586/596 | Timestep 5950 | LR 0.0001000000 | Loss 0.039289
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:53	Epoch 9 | Batch 596/596 | Timestep 5960 | LR 0.0001000000 | Loss 0.017192
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:36:53	** Evaluating on validation dataset **
# INFO	root	Sun, 14 Apr 2024 21:37:33
#                    precision    recall  f1-score   support
#
#               AGE     0.9181    0.9607    0.9389       280
#             AWARD     0.6639    0.8587    0.7488        92
#              CITY     0.8300    0.9663    0.8930       475
#           COUNTRY     0.9605    0.9773    0.9688       970
#             CRIME     0.6038    0.7711    0.6772        83
#              DATE     0.9033    0.9147    0.9090       950
#           DISEASE     0.6769    0.6984    0.6875        63
#          DISTRICT     0.7167    0.7167    0.7167        60
#             EVENT     0.7185    0.8155    0.7640      1133
#          FACILITY     0.6887    0.7935    0.7374       184
#            FAMILY     0.6667    0.8000    0.7273        10
#          IDEOLOGY     0.6695    0.8977    0.7670        88
#          LANGUAGE     1.0000    0.9565    0.9778        23
#               LAW     0.6789    0.8506    0.7551        87
#          LOCATION     0.7475    0.7957    0.7708        93
#             MONEY     0.7609    0.8537    0.8046        41
#       NATIONALITY     0.8111    0.8588    0.8343       170
#            NUMBER     0.8962    0.9420    0.9186       431
#           ORDINAL     0.9000    0.9783    0.9375       230
#      ORGANIZATION     0.8631    0.9380    0.8990      1210
#           PENALTY     0.4615    0.5455    0.5000        22
#           PERCENT     1.0000    1.0000    1.0000        17
#            PERSON     0.9638    0.9792    0.9715      1877
#           PRODUCT     0.8899    0.8584    0.8739       113
#        PROFESSION     0.8481    0.9349    0.8894      1475
#          RELIGION     0.7049    0.9773    0.8190        44
# STATE_OR_PROVINCE     0.9308    0.8013    0.8612       151
#              TIME     0.7826    0.8090    0.7956        89
#       WORK_OF_ART     0.7143    0.8333    0.7692        78
#
#         micro avg     0.8573    0.9197    0.8874     10539
#         macro avg     0.7921    0.8649    0.8246     10539
#      weighted avg     0.8623    0.9197    0.8891     10539
#
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:37:53	Epoch 9 | Timestep 5960 | Train Loss 0.072006 | Val Loss 0.122639 | F1 0.887434
# INFO	arabiner.trainers.BertNestedTrainer	Sun, 14 Apr 2024 21:37:53	Early termination triggered

# %% [markdown]
# ## Save checkpoint to Google Drive
# (Optional action)

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !zip -r third_attempt.zip ArabicNER/results
# Out:
#   adding: ArabicNER/results/ (stored 0%)
#   adding: ArabicNER/results/tag_vocab.pkl (deflated 86%)
#   adding: ArabicNER/results/predictions.txt (deflated 93%)
#   adding: ArabicNER/results/tensorboard/ (stored 0%)
#   adding: ArabicNER/results/tensorboard/Metrics_test_micro_f1/ (stored 0%)
#   adding: ArabicNER/results/tensorboard/Metrics_test_micro_f1/events.out.tfevents.1713128392.65cd2fa4555d.3088.7 (deflated 33%)
#   adding: ArabicNER/results/tensorboard/Metrics_test_precision/ (stored 0%)
#   adding: ArabicNER/results/tensorboard/Metrics_test_precision/events.out.tfevents.1713128392.65cd2fa4555d.3088.8 (deflated 33%)
#   adding: ArabicNER/results/tensorboard/Metrics_test_recall/ (stored 0%)
#   adding: ArabicNER/results/tensorboard/Metrics_test_recall/events.out.tfevents.1713128392.65cd2fa4555d.3088.9 (deflated 33%)
#   adding: ArabicNER/results/tensorboard/Loss_test_loss/ (stored 0%)
#   adding: ArabicNER/results/tensorboard/Loss_test_loss/events.out.tfevents.1713128392.65cd2fa4555d.3088.3 (deflated 31%)
#   adding: ArabicNER/results/tensorboard/Metrics_val_micro_f1/ (stored 0%)
#   adding: ArabicNER/results/tensorboard/Metrics_val_micro_f1/events.out.tfevents.1713128392.65cd2fa4555d.3088.4 (deflated 43%)
#   adding: ArabicNER/results/tensorboard/Loss_train_loss/ (stored 0%)
#   adding: ArabicNER/results/tensorboard/Loss_train_loss/events.out.tfevents.1713128392.65cd2fa4555d.3088.1 (deflated 40%)
#   adding: ArabicNER/results/tensorboard/Loss_val_loss/ (stored 0%)
#   adding: ArabicNER/results/tensorboard/Loss_val_loss/events.out.tfevents.1713128392.65cd2fa4555d.3088.2 (deflated 40%)
#   adding: ArabicNER/results/tensorboard/events.out.tfevents.1713128080.65cd2fa4555d.3088.0 (deflated 9%)
#   adding: ArabicNER/results/tensorboard/Metrics_val_recall/ (stored 0%)
#   adding: ArabicNER/results/tensorboard/Metrics_val_recall/events.out.tfevents.1713128392.65cd2fa4555d.3088.6 (deflated 43%)
#   adding: ArabicNER/results/tensorboard/Metrics_val_precision/ (stored 0%)
#   adding: ArabicNER/results/tensorboard/Metrics_val_precision/events.out.tfevents.1713128392.65cd2fa4555d.3088.5 (deflated 43%)
#   adding: ArabicNER/results/args.json (deflated 75%)
#   adding: ArabicNER/results/checkpoints/ (stored 0%)
#   adding: ArabicNER/results/checkpoints/checkpoint_4.pt (deflated 31%)
#   adding: ArabicNER/results/checkpoints/.ipynb_checkpoints/ (stored 0%)
#   adding: ArabicNER/results/train.log (deflated 87%)

# %%
# !cp third_attempt.zip '/content/gdrive/MyDrive/Innopolis/PMLDL'

# %% [markdown]
# ## Load checkpoint from Google Drive
# (If you want to skip training)

# %%
# !cp '/content/gdrive/MyDrive/Innopolis/PMLDL/third_attempt.zip' third_attempt.zip
# !mkdir ArabicNER/results
# !unzip third_attempt.zip -d ArabicNER/results
# !cp -r ArabicNER/results/ArabicNER/results/. ArabicNER/results
# !rm -r ArabicNER/results/ArabicNER
# Out:
# Archive:  third_attempt.zip
#    creating: ArabicNER/results/ArabicNER/results/
#   inflating: ArabicNER/results/ArabicNER/results/tag_vocab.pkl
#   inflating: ArabicNER/results/ArabicNER/results/predictions.txt
#    creating: ArabicNER/results/ArabicNER/results/tensorboard/
#    creating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_test_micro_f1/
#   inflating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_test_micro_f1/events.out.tfevents.1713128392.65cd2fa4555d.3088.7
#    creating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_test_precision/
#   inflating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_test_precision/events.out.tfevents.1713128392.65cd2fa4555d.3088.8
#    creating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_test_recall/
#   inflating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_test_recall/events.out.tfevents.1713128392.65cd2fa4555d.3088.9
#    creating: ArabicNER/results/ArabicNER/results/tensorboard/Loss_test_loss/
#   inflating: ArabicNER/results/ArabicNER/results/tensorboard/Loss_test_loss/events.out.tfevents.1713128392.65cd2fa4555d.3088.3
#    creating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_val_micro_f1/
#   inflating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_val_micro_f1/events.out.tfevents.1713128392.65cd2fa4555d.3088.4
#    creating: ArabicNER/results/ArabicNER/results/tensorboard/Loss_train_loss/
#   inflating: ArabicNER/results/ArabicNER/results/tensorboard/Loss_train_loss/events.out.tfevents.1713128392.65cd2fa4555d.3088.1
#    creating: ArabicNER/results/ArabicNER/results/tensorboard/Loss_val_loss/
#   inflating: ArabicNER/results/ArabicNER/results/tensorboard/Loss_val_loss/events.out.tfevents.1713128392.65cd2fa4555d.3088.2
#   inflating: ArabicNER/results/ArabicNER/results/tensorboard/events.out.tfevents.1713128080.65cd2fa4555d.3088.0
#    creating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_val_recall/
#   inflating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_val_recall/events.out.tfevents.1713128392.65cd2fa4555d.3088.6
#    creating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_val_precision/
#   inflating: ArabicNER/results/ArabicNER/results/tensorboard/Metrics_val_precision/events.out.tfevents.1713128392.65cd2fa4555d.3088.5
#   inflating: ArabicNER/results/ArabicNER/results/args.json
#    creating: ArabicNER/results/ArabicNER/results/checkpoints/
#   inflating: ArabicNER/results/ArabicNER/results/checkpoints/checkpoint_4.pt
#    creating: ArabicNER/results/ArabicNER/results/checkpoints/.ipynb_checkpoints/
#   inflating: ArabicNER/results/ArabicNER/results/train.log

# %% [markdown]
# # Model inference

# %%
import sys
sys.path.append('ArabicNER')

# %%
from typing import List, Tuple
from arabiner.data.datasets import Token
from torchtext.vocab import vocab
from torchtext.vocab import Vocab
from collections import Counter


def custom_text2segments(text: str) -> Tuple[List[Token], Vocab, List[Tuple[int, int]]]:
    """
    Split text into tokens and their location with vocabulary of a text.

    Parameters:
        text (str): Text to process.
    Return:
        (List[Token]): Tokens from the text
        (Vocab): Word vocabulary.
        (List[Tuple[int, int]]): List of the token's spans.
    """
    # Tokenize text
    tokenized = list(tokenize(text))
    # Create token lists
    dataset = [[Token(text=token.text, gold_tag=["O"]) for token in tokenized]]
    # Get token spans
    spans = [(token.start, token.stop) for token in tokenized]
    # Get all tokens in flat list
    tokens = [token.text for segment in dataset for token in segment]

    # Generate vocabs for the tokens
    segment_vocab = vocab(Counter(tokens), specials=["UNK"])
    return dataset, segment_vocab, spans

# %%
from collections import namedtuple
from arabiner.utils.helpers import load_checkpoint
from arabiner.utils.data import get_dataloaders, text2segments
from tqdm import tqdm

# Load tagger
tagger, tag_vocab, train_config = load_checkpoint("ArabicNER/results")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def get_model_results(input_text: str) -> List[Tuple[str, List[str], Tuple[int, int]]]:
    """
    Apply NER annotation on provided text.

    Parameters:
        input_text (str): The text for NER annotation.
    Return:
        (List[Tuple[str, List[str], Tuple[int, int]]]): List of tokens with all NER linked to it and token's span.
    """
    # Convert text to a tagger dataset and index the tokens in args.text
    dataset, token_vocab, spans = custom_text2segments(input_text)

    vocabs = namedtuple("Vocab", ["tags", "tokens"])
    vocab = vocabs(tokens=token_vocab, tags=tag_vocab)

    # From the datasets generate the dataloaders
    dataloader = get_dataloaders(
        (dataset,),
        vocab,
        train_config.data_config,
        batch_size=32,
        shuffle=(False,),
    )[0]

    # Perform inference on the text and get back the tagged segments
    segments = tagger.infer(dataloader)

    inference_result = []
    # Print results
    for segment in segments:
        s = [
            (token.text, [t['tag'] for t in token.pred_tag], spans[i]) for i, token in enumerate(segment)
        ]
        inference_result.extend(s)
    return inference_result

# %%
get_model_results("Сэмюэл Л. Джексон вернется к образу Ника Фьюри в «Капитане Марвел» Сэмюэл Лерой Джексон Сэмюэл Лерой Джексон исполнит роль Ника Фьюри в «Капитане Марвел». Он сыграет в фильме вместе с Бри Ларсон в готовящемся проекте Marvel Studios. Джексон подписал контракт с Marvel Studios на 9 фильмов, 7 уже вышло. Актёр в этом амплуа предстал ещё в двух эпизодах сериала «Агенты „Щ.И.Т.“» и дал свой голос в трёх видеоигр. Съёмки новой ленты стартуют в феврале 2018 года. Релиз намечен на 7 марта 2019 года.")
# Out:
# tokenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# [('Сэмюэл',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (0, 6)),
#  ('Л',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (7, 8)),
#  ('.',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (8, 9)),
#  ('Джексон',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (10, 17)),
#  ('вернется',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (18, 26)),
#  ('к',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (27, 28)),
#  ('образу',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (29, 35)),
#  ('Ника',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (36, 40)),
#  ('Фьюри',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (41, 46)),
#  ('в',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (47, 48)),
#  ('«',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (49, 50)),
#  ('Капитане',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PROFESSION',
#    'O',
#    'O',
#    'O',
#    'B-WORK_OF_ART'],
#   (50, 58)),
#  ('Марвел',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-WORK_OF_ART'],
#   (59, 65)),
#  ('»',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (65, 66)),
#  ('Сэмюэл',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (67, 73)),
#  ('Лерой',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (74, 79)),
#  ('Джексон',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (80, 87)),
#  ('Сэмюэл',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (88, 94)),
#  ('Лерой',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (95, 100)),
#  ('Джексон',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (101, 108)),
#  ('исполнит',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (109, 117)),
#  ('роль',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (118, 122)),
#  ('Ника',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (123, 127)),
#  ('Фьюри',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (128, 133)),
#  ('в',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (134, 135)),
#  ('«',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (136, 137)),
#  ('Капитане',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PROFESSION',
#    'O',
#    'O',
#    'O',
#    'B-WORK_OF_ART'],
#   (137, 145)),
#  ('Марвел',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-WORK_OF_ART'],
#   (146, 152)),
#  ('»',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (152, 153)),
#  ('.',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (153, 154)),
#  ('Он',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (155, 157)),
#  ('сыграет',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (158, 165)),
#  ('в',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (166, 167)),
#  ('фильме',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (168, 174)),
#  ('вместе',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (175, 181)),
#  ('с',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (182, 183)),
#  ('Бри',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (184, 187)),
#  ('Ларсон',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (188, 194)),
#  ('в',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (195, 196)),
#  ('готовящемся',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (197, 208)),
#  ('проекте',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (209, 216)),
#  ('Marvel',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORGANIZATION',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (217, 223)),
#  ('Studios',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-ORGANIZATION',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (224, 231)),
#  ('.',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (231, 232)),
#  ('Джексон',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (233, 240)),
#  ('подписал',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-EVENT',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (241, 249)),
#  ('контракт',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-EVENT',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (250, 258)),
#  ('с',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (259, 260)),
#  ('Marvel',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORGANIZATION',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (261, 267)),
#  ('Studios',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-ORGANIZATION',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (268, 275)),
#  ('на',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (276, 278)),
#  ('9',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-NUMBER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (279, 280)),
#  ('фильмов',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (281, 288)),
#  (',',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (288, 289)),
#  ('7',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-NUMBER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (290, 291)),
#  ('уже',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (292, 295)),
#  ('вышло',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (296, 301)),
#  ('.',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (301, 302)),
#  ('Актёр',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PROFESSION',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (303, 308)),
#  ('в',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (309, 310)),
#  ('этом',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (311, 315)),
#  ('амплуа',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (316, 322)),
#  ('предстал',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (323, 331)),
#  ('ещё',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (332, 335)),
#  ('в',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (336, 337)),
#  ('двух',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-NUMBER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (338, 342)),
#  ('эпизодах',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (343, 351)),
#  ('сериала',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (352, 359)),
#  ('«',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (360, 361)),
#  ('Агенты',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PROFESSION',
#    'O',
#    'O',
#    'O',
#    'B-WORK_OF_ART'],
#   (361, 367)),
#  ('„',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-WORK_OF_ART'],
#   (368, 369)),
#  ('Щ',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-WORK_OF_ART'],
#   (369, 370)),
#  ('.',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-WORK_OF_ART'],
#   (370, 371)),
#  ('И',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-WORK_OF_ART'],
#   (371, 372)),
#  ('.',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-WORK_OF_ART'],
#   (372, 373)),
#  ('Т',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-WORK_OF_ART'],
#   (373, 374)),
#  ('.',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-WORK_OF_ART'],
#   (374, 375)),
#  ('“',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (375, 376)),
#  ('»',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (376, 377)),
#  ('и',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (378, 379)),
#  ('дал',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (380, 383)),
#  ('свой',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (384, 388)),
#  ('голос',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (389, 394)),
#  ('в',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (395, 396)),
#  ('трёх',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-DATE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (397, 401)),
#  ('видеоигр',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (402, 410)),
#  ('.',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (410, 411)),
#  ('Съёмки',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (412, 418)),
#  ('новой',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (419, 424)),
#  ('ленты',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (425, 430)),
#  ('стартуют',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (431, 439)),
#  ('в',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-DATE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (440, 441)),
#  ('феврале',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-DATE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (442, 449)),
#  ('2018',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-DATE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (450, 454)),
#  ('года',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-DATE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (455, 459)),
#  ('.',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (459, 460)),
#  ('Релиз',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (461, 466)),
#  ('намечен',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (467, 474)),
#  ('на',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-DATE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (475, 477)),
#  ('7',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-DATE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (478, 479)),
#  ('марта',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-DATE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (480, 485)),
#  ('2019',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-DATE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (486, 490)),
#  ('года',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-DATE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (491, 495)),
#  ('.',
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   (495, 496))]

# %%
import json

def inference_dataset(file_path: str) -> None:
    """
    Do inference on the test dataset and save the result in submit file format.

    Parameters:
        file_path (str): Path to dataset file.
    """
    sentences = []
    sentence_ids = []

    # Read all lines from dataset file
    with open(file_path) as dataset_file:
        lines = dataset_file.readlines()

    # Write into resulting file
    with open("result.jsonl", "w") as result_file:
        for line in tqdm(lines):
            # Read content: sentence and id of sentence
            content = json.loads(line)
            sentence = content["senences"]
            sentence_id = content["id"]

            # Get tags (NER) for sentence
            tagged_sentence = get_model_results(sentence)
            # Prepare variables for formatting
            new_content = dict()
            ners = []
            last_tags = [None]*29
            # Format the tags for tokens into tag spans
            for tag in tagged_sentence:
                start_pos, end_pos = tag[2]
                end_pos = end_pos - 1
                for i, layer in enumerate(tag[1]):
                    if layer == 'O':
                        if last_tags[i] is not None:
                            ners.append(last_tags[i])
                        last_tags[i] = None
                    elif layer[:2] == 'B-':
                        if last_tags[i] is not None:
                            ners.append(last_tags[i])
                        last_tags[i] = [start_pos, end_pos, layer[2:]]
                    elif layer[:2] == "I-":
                        if last_tags[i] is None:
                            last_tags[i] = [start_pos, end_pos, layer[2:]]
                        else:
                            last_tags[i][1] = end_pos
            for ner in last_tags:
                if ner is not None:
                    ners.append(ner)
            # Save formatted data
            new_content["id"] = sentence_id
            new_content["ners"] = ners
            result_file.write(json.dumps(new_content)+"\n")

# %% [markdown]
# ## Predict tags for test set

# %%
# Load into notebook dev.jsonl in content folder!
inference_dataset("dev.jsonl")
# Out:
# 100%|██████████| 65/65 [00:27<00:00,  2.39it/s]
